# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os, sys, glob
from PIL import Image
import io
import pickle
from collections import OrderedDict

# %%
dirstem = os.path.join(os.path.expanduser('~'), 'neuroailab', 'trials', 'domi_*')
trials = sorted(glob.glob(dirstem), key=lambda t: int(t.split('_')[-1]))
trials = {int(trial.split('_')[-1]): trial for trial in trials}
trials
# Out:
# {0: '/Users/db/neuroailab/trials/domi_0',
#  2: '/Users/db/neuroailab/trials/domi_2',
#  3: '/Users/db/neuroailab/trials/domi_3',
#  4: '/Users/db/neuroailab/trials/domi_4',
#  5: '/Users/db/neuroailab/trials/domi_5',
#  6: '/Users/db/neuroailab/trials/domi_6',
#  7: '/Users/db/neuroailab/trials/domi_7',
#  8: '/Users/db/neuroailab/trials/domi_8',
#  9: '/Users/db/neuroailab/trials/domi_9',
#  10: '/Users/db/neuroailab/trials/domi_10',
#  11: '/Users/db/neuroailab/trials/domi_11',
#  12: '/Users/db/neuroailab/trials/domi_12',
#  13: '/Users/db/neuroailab/trials/domi_13',
#  14: '/Users/db/neuroailab/trials/domi_14',
#  15: '/Users/db/neuroailab/trials/domi_15'}

# %%
TDW_DIR = trials[15]
TNUM = 1
FILE = "%04d.hdf5" % TNUM
print(FILE)
view_frame = 0
f = h5py.File(os.path.join(TDW_DIR, FILE))

# print the data structure
print("top keys", [k for k in f.keys()])
frames = f['frames']
n_frames = len([k for k in frames.keys()])
print("num frames: {}".format(n_frames))
view_frame = np.minimum(view_frame, n_frames - 1)
frame = frames["%04d" % (view_frame)]
print("frame data keys", [k for k in frame.keys()])
img = frame['images']
print("image keys", [k for k in img.keys()])
_img = Image.open(io.BytesIO(img["_img"][:]))
_img
# Out:
# 0001.hdf5
# top keys ['frames', 'static']
# num frames: 97
# frame data keys ['camera_matrices', 'collisions', 'env_collisions', 'images', 'objects']
# image keys ['_depth', '_flow', '_id', '_img', '_normals']
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x1103B06D8>

# %%
# %matplotlib nbagg
SAVE = False

def get_frame(f, idx, imkey='_img', N=n_frames):
    fkeys = sorted([k for k in f['frames'].keys()])
    img = f['frames'][fkeys[idx % N]]['images']
    return np.array(Image.open(io.BytesIO(img[imkey][:]))), len(fkeys)

idx = 0

fig, axes = plt.subplots(figsize=(4,4))
fr0, n_frames = get_frame(f,idx)
im = plt.imshow(fr0, origin='upper')

def animate(*args):
    global idx
    
    fr, N = get_frame(f, idx)
    im.set_array(fr)
    idx += 1
    idx %= N
    
    return im,

def savegif(ani, directory=TDW_DIR, file=FILE):
    import os
    f = os.path.join(directory, file.split('.')[0]) + ".gif"
    writergif = animation.PillowWriter(fps=48)
    ani.save(f, writer=writergif)

ani = animation.FuncAnimation(fig, animate, interval=10, save_count=n_frames)
plt.show()

if SAVE:
    savegif(ani, TDW_DIR, FILE)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# # Check Metadata

# %%
skeys = [k for k in f['static'].keys()]
print(skeys)

obj_ids = [oid for oid in f['static']['object_ids']]
print(obj_ids)
# Out:
# ['bounciness', 'color', 'dynamic_friction', 'mass', 'object_ids', 'probe_type', 'scale_x', 'scale_y', 'scale_z', 'static_friction', 'target_rotation', 'target_type']
# [16558677, 7728878]

# %%
key = 'static_friction'
meta = f['static'][key]
print(np.array(meta))
# Out:
# [0.86571084 0.79456583]
